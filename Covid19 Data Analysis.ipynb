# %%
#importing the modules-pandas,seaborn,numpy,marpotlib.pyplot#
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pit
print("modules are imported ")
# Out:
# modules are imported

# %%
#importing Covid19 dataset#
#importing covid19_Confirmed_dataset.csv from /Covid19 datastes folder#
covid19_Confirmed_dataset_csv=pd.read_csv("C:\\Users\\Prabhanshu Gautam\\Documents\\Covid19 datasets\covid19_Confirmed_dataset.csv")
covid19_Confirmed_dataset_csv.head(10) #to load csv file or data#
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
#check the shape of data frame
#no. of rows and columns
covid19_Confirmed_dataset_csv.shape
# Out:
# (266, 104)

# %%
#deleting useless data from dataset
covid19_Confirmed_dataset_csv.drop(["Lat","Long"],axis=1,inplace=True)#"method return the copy of covid19_Confirmed_dataset without data_frame.head() 
covid19_Confirmed_dataset_csv.head()                                  #without latitude and longitude [inplace=true]"
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
#aggregating the rows by country 
data_frame_agg=covid19_Confirmed_dataset_csv.groupby("Country/Region").sum() 
data_frame_agg.head(20)
#after the afreggating the dataset is shown by country/region not by indices
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
# Azerbaijan                 0        0        0        0        0        0
# ...

# %%
data_frame_agg.shape
#it will give the no. of rows which are country/region and no. of column which are dates from dataset
# Out:
# (187, 100)

# %%
#visualizing data related to a country for better understanding of data
data_frame_agg.loc["China"] #locate the row with the name of the country
# Out:
# 1/22/20      548
# 1/23/20      643
# 1/24/20      920
# 1/25/20     1406
# 1/26/20     2075
#            ...
# 4/26/20    83912
# 4/27/20    83918
# 4/28/20    83940
# 4/29/20    83944
# 4/30/20    83956
# Name: China, Length: 100, dtype: int64

# %%
#plotting the commulative number of confirmed cases related to the china 
data_frame_agg.loc["China"].plot()

# %%
#comparing the confirmed cases of two country "China" and "India"
data_frame_agg.loc["India"].plot()
data_frame_agg.loc["China"].plot()
pit.legend() #creating labels for indicating the plot of the particular country

# %%
data_frame_agg.loc["India"][:15].plot() #showing the cases for the first 15 date in the dataset of covid 19

# %%
#claculating and plotting first maximum number of confirm cases
data_frame_agg.loc["Belgium"].diff().plot()

# %%
data_frame_agg.loc["India"].diff().max() #maximum no. of cases in one day from the dataset in India
# Out:
# 1893.0

# %%
data_frame_agg.loc["France"].diff().max() #maximum no. of cases in one day from the dataset in France
# Out:
# 26849.0

# %%
data_frame_agg.loc["Afghanistan"].diff().max() #maximum no. of cases in one day from the dataset in China
# Out:
# 232.0

# %%
#find maximum infection rate for all country
countries=list(data_frame_agg.index) #creatinlist of countries having indexes
max_infection=[] #new list for max infectin cases in day
for i in countries: 
    max_infection.append(data_frame_agg.loc[i].diff().max()) #appending all the maximum cases of countries in max_infection
max_infection
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
data_frame_agg["max_infection_rate"]=max_infection #created new column for maximum ifection rate in country
data_frame_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
#creating new data frame for with only needed column
infected_data=pd.DataFrame(data_frame_agg["max_infection_rate"])
infected_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
#inporting another csv file or data
happiness_report_csv=pd.read_csv("C:\\Users\\Prabhanshu Gautam\\Documents\\Covid19 datasets\worldwide_happiness_report.csv")
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#dropping useless column from the data set 
useless_column=["Overall rank","Score","Generosity","Perceptions of corruption"] #cloumn to be dropped
happiness_report_csv.drop(useless_column,axis=1,inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
#changing indices of the data set to the country
happiness_report_csv.set_index(["Country or region"],inplace=True)
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
#joining the to data set of covid19_confirmed and word happiness report datasets
#covid19 datasets
infected_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
infected_data.shape
# Out:
# (187, 1)

# %%
#world happiness report
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %%
#performing join for both datasets
#here,we performed INNER JOIN as the country in world happiness report are less than infected data
infected_data.join(happiness_report_csv,how="inner")
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                  29.0           0.960           1.427
# Vietnam                    19.0           0.741           1.346
# Yemen                       5.0           0.287           1.163
# Zambia                      9.0           0.578           1.058
# Zimbabwe                    8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
#storing data in dataframe
data=infected_data.join(happiness_report_csv,how="inner")
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
#correlation matrix
#relation between the different factor affecting the life in the covid19..the greater the relation value more good it is,
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %%
#Visualization of the result
#visualiZing the result in terms of figure and graphs to understand our analysis
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
#plotting relation between GDP per capital and Max_infected_rate
x=data["GDP per capita"]
y=data["max_infection_rate"]
sns.scatterplot(x,y)

# %%
sns.scterplot(x,np.log(y)) #applying log scaling changes scale for y axis for better detail of plotting

# %%
sns.regplot(x,np.log(y))

# %%
x=data["Social support"]
y=data["Healthy life expectancy"]
sns.scatterplot(x,y)

# %%
sns.regplot(x,np.log(y))
